# %%
import numpy as np

# %%
np.random.choice(range(6000),1000).tolist()
# Out:
# [1981,
#  2764,
#  1323,
#  4703,
#  4211,
#  4135,
#  668,
#  2882,
#  1966,
#  3853,
#  3868,
#  3154,
#  1104,
#  4024,
#  5369,
#  3182,
#  1264,
#  3998,
#  3418,
#  2937,
#  2892,
#  3600,
#  2486,
#  1002,
#  3219,
#  4565,
#  5191,
#  3855,
#  103,
#  933,
#  5315,
#  3322,
#  1830,
#  3170,
#  3034,
#  236,
#  1185,
#  701,
#  3284,
#  2575,
#  1085,
#  3001,
#  3939,
#  3499,
#  895,
#  2656,
#  771,
#  4614,
#  1127,
#  3181,
#  2283,
#  5766,
#  661,
#  2343,
#  362,
#  1404,
#  987,
#  2375,
#  3159,
#  568,
#  1240,
#  4986,
#  2048,
#  5523,
#  993,
#  562,
#  803,
#  3270,
#  4871,
#  470,
#  3197,
#  5347,
#  702,
#  5275,
#  5373,
#  1204,
#  162,
#  1226,
#  1895,
#  2766,
#  4440,
#  1499,
#  3941,
#  928,
#  1575,
#  536,
#  4957,
#  4912,
#  3053,
#  5118,
#  4659,
#  1031,
#  335,
#  310,
#  3473,
#  4183,
#  5118,
#  5077,
#  1327,
#  487,
#  3994,
#  2627,
#  1247,
#  2355,
#  5872,
#  5107,
#  3049,
#  2378,
#  4697,
#  5107,
#  2045,
#  4521,
#  1124,
# ...
