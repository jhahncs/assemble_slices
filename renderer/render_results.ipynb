# %%
import os
import hydra
import json
import bpy
#sudo apt-get install ffmpeg
from omegaconf import OmegaConf,open_dict
import omegaconf

# %%
config_home_dir = '/users/j/a/jahn25/puzzlepp/config'
config_home_dir = '../config'

cfg_auto_aggl = omegaconf.OmegaConf.load(config_home_dir+'/auto_aggl.yaml')


cfg = OmegaConf.merge( cfg_auto_aggl )

data_home_dir = '/disk2/data/breaking_bad/'
data_home_dir = '/disk2/data/shape_dataset/'

cfg.experiment_output_path = ''
cfg.inference_dir= data_home_dir+'results'
cfg.renderer.output_path = data_home_dir+'results_render/'
cfg.renderer.mesh_path = f'{data_home_dir}/data/'

# %%
import importlib
import myrenderer
importlib.reload(myrenderer)

from myrenderer import MyRenderer

# %%
renderer = MyRenderer(cfg)


#save_dir = data_root_dir+'/results' #cfg.renderer.output_path
    
sampled_files = renderer.sample_data_files()
sampled_files = ['1']
# sampled_files = ["1"]

for file in sampled_files:
    transformation, gt_transformation, acc, init_pose = renderer.load_transformation_data(file)
    print('==============transformation===============')
    print(transformation.shape)
    print('==============gt_transformation===============')
    print(gt_transformation.shape)
    print('==============init_pose===============')
    print(init_pose)
    parts = renderer.load_mesh_parts(file, gt_transformation, init_pose)
    print(file)
    print('==============parts===============')
    print(parts)
    save_path = cfg.renderer.output_path+f'{file}'
    os.makedirs(save_path, exist_ok=True)

    renderer.save_img(parts, gt_transformation, gt_transformation, init_pose, os.path.join(save_path, "gt.png"))

    if True:
        renderer.clean()
        break



    
    frame = 0

    # bpy.ops.wm.save_mainfile(filepath=save_path + "test" + '.blend')

    for i in range(transformation.shape[0]):
        renderer.render_parts(
            parts, 
            gt_transformation, 
            transformation[i], 
            init_pose, 
            frame,
        )
        frame += 1


    imgs_path = os.path.join(save_path, "imgs")
    os.makedirs(imgs_path, exist_ok=True)
    renderer.save_video(imgs_path=imgs_path, video_path=os.path.join(save_path, "video.mp4"), frame=frame)
    renderer.clean()


# In[ ]:
# Out:
# cycles rendering with: GPU
# ==============transformation===============
# (20, 16, 7)
# ==============gt_transformation===============
# (16, 7)
# ==============init_pose===============
# [ 0.01556611 -0.46343011 -0.07509192 -0.50846085 -0.44456888  0.46954936
#   0.56863826]
# 1
# ==============parts===============
# [bpy.data.objects['piece_0'], bpy.data.objects['piece_1'], bpy.data.objects['piece_10'], bpy.data.objects['piece_11'], bpy.data.objects['piece_12'], bpy.data.objects['piece_13'], bpy.data.objects['piece_14'], bpy.data.objects['piece_15'], bpy.data.objects['piece_2'], bpy.data.objects['piece_3'], bpy.data.objects['piece_4'], bpy.data.objects['piece_5'], bpy.data.objects['piece_6'], bpy.data.objects['piece_7'], bpy.data.objects['piece_8'], bpy.data.objects['piece_9']]
# OBJ import of 'piece_0.obj' took 1.37 ms
# OBJ import of 'piece_1.obj' took 1.19 ms
# OBJ import of 'piece_10.obj' took 1.01 ms
# OBJ import of 'piece_11.obj' took 0.95 ms
# OBJ import of 'piece_12.obj' took 0.99 ms
# OBJ import of 'piece_13.obj' took 0.84 ms
# OBJ import of 'piece_14.obj' took 0.89 ms
# OBJ import of 'piece_15.obj' took 0.97 ms
# OBJ import of 'piece_2.obj' took 0.83 ms
# OBJ import of 'piece_3.obj' took 1.01 ms
# OBJ import of 'piece_4.obj' took 0.95 ms
# OBJ import of 'piece_5.obj' took 1.13 ms
# OBJ import of 'piece_6.obj' took 1.02 ms
# OBJ import of 'piece_7.obj' took 0.98 ms
# OBJ import of 'piece_8.obj' took 1.03 ms
# OBJ import of 'piece_9.obj' took 1.10 ms
# Fra:1 Mem:17.68M (Peak 17.68M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | Plane
# Fra:1 Mem:17.68M (Peak 17.68M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | piece_0
# Fra:1 Mem:17.68M (Peak 17.68M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | piece_15
# Fra:1 Mem:17.69M (Peak 17.69M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | piece_4
# Fra:1 Mem:17.74M (Peak 17.74M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | piece_9
# Fra:1 Mem:18.44M (Peak 18.44M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:16.67M (Peak 18.44M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:16.67M (Peak 18.44M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:16.67M (Peak 18.44M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:16.67M (Peak 18.44M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:16.77M (Peak 18.44M) | Time:00:00.01 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:16.77M (Peak 18.44M) | Time:00:00.01 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:16.77M (Peak 18.44M) | Time:00:00.01 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:16.77M (Peak 18.44M) | Time:00:00.01 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:16.77M (Peak 18.44M) | Time:00:00.01 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:16.77M (Peak 18.44M) | Time:00:00.01 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:16.77M (Peak 18.44M) | Time:00:00.01 | Mem:0.02M, Peak:0.02M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:16.77M (Peak 18.44M) | Time:00:00.01 | Mem:0.02M, Peak:0.02M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:16.77M (Peak 18.44M) | Time:00:00.01 | Mem:0.02M, Peak:0.02M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:16.77M (Peak 18.44M) | Time:00:00.01 | Mem:0.02M, Peak:0.02M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:16.90M (Peak 18.44M) | Time:00:00.01 | Mem:0.02M, Peak:0.02M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:16.96M (Peak 18.44M) | Time:00:00.01 | Mem:0.02M, Peak:0.02M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:16.96M (Peak 18.44M) | Time:00:00.01 | Mem:0.08M, Peak:0.08M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:16.96M (Peak 18.44M) | Time:00:00.01 | Mem:0.08M, Peak:0.08M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:1 Mem:16.96M (Peak 18.44M) | Time:00:00.01 | Mem:0.33M, Peak:0.33M | Scene, ViewLayer | Updating Scene BVH | Building BVH 0%
# Fra:1 Mem:16.96M (Peak 18.44M) | Time:00:00.01 | Mem:0.52M, Peak:0.77M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:16.96M (Peak 18.44M) | Time:00:00.01 | Mem:0.52M, Peak:0.77M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:1 Mem:17.27M (Peak 18.44M) | Time:00:00.01 | Mem:0.52M, Peak:0.77M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:1 Mem:17.27M (Peak 18.44M) | Time:00:00.01 | Mem:0.84M, Peak:0.84M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:17.27M (Peak 18.44M) | Time:00:00.01 | Mem:0.84M, Peak:0.84M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:17.27M (Peak 18.44M) | Time:00:00.01 | Mem:0.84M, Peak:0.84M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:17.27M (Peak 18.44M) | Time:00:00.01 | Mem:0.84M, Peak:0.84M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:17.27M (Peak 18.44M) | Time:00:00.01 | Mem:0.84M, Peak:0.84M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:17.27M (Peak 18.44M) | Time:00:00.01 | Mem:0.92M, Peak:0.92M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:17.27M (Peak 18.44M) | Time:00:00.01 | Mem:0.92M, Peak:0.92M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:17.27M (Peak 18.44M) | Time:00:00.01 | Mem:0.92M, Peak:0.92M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:17.27M (Peak 18.44M) | Time:00:00.01 | Mem:0.92M, Peak:0.92M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:17.28M (Peak 18.44M) | Time:00:00.01 | Mem:0.84M, Peak:0.92M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:17.28M (Peak 18.44M) | Time:00:00.01 | Mem:0.92M, Peak:0.92M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:17.28M (Peak 18.44M) | Time:00:00.01 | Mem:0.92M, Peak:0.92M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:17.28M (Peak 18.44M) | Time:00:00.01 | Mem:0.92M, Peak:0.92M | Scene, ViewLayer | Sample 0/200
# Fra:1 Mem:289.49M (Peak 289.49M) | Time:00:01.18 | Remaining:03:51.08 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Sample 1/200
# Fra:1 Mem:289.49M (Peak 289.49M) | Time:00:27.19 | Remaining:02:17.52 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Sample 33/200
# Fra:1 Mem:289.49M (Peak 289.49M) | Time:00:53.17 | Remaining:01:50.39 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Sample 65/200
# Fra:1 Mem:289.49M (Peak 289.49M) | Time:01:05.34 | Remaining:01:37.99 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Sample 80/200
# Fra:1 Mem:289.49M (Peak 289.49M) | Time:01:05.86 | Remaining:01:11.32 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Sample 96/200
# Fra:1 Mem:289.49M (Peak 289.49M) | Time:01:06.05 | Remaining:00:51.88 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Sample 112/200
# Fra:1 Mem:289.49M (Peak 289.49M) | Time:01:06.15 | Remaining:00:37.20 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Sample 128/200
# Fra:1 Mem:289.49M (Peak 289.49M) | Time:01:06.25 | Remaining:00:25.75 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Sample 144/200
# Fra:1 Mem:289.49M (Peak 289.49M) | Time:01:06.30 | Remaining:00:16.57 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Sample 160/200
# Fra:1 Mem:289.49M (Peak 289.49M) | Time:01:06.37 | Remaining:00:09.04 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Sample 176/200
# Fra:1 Mem:289.49M (Peak 289.49M) | Time:01:06.42 | Remaining:00:02.76 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Sample 192/200
# Fra:1 Mem:353.49M (Peak 481.49M) | Time:01:06.61 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Sample 200/200
# Fra:1 Mem:353.49M (Peak 481.49M) | Time:01:06.61 | Mem:272.92M, Peak:272.92M | Scene, ViewLayer | Finished
# Fra:1 Mem:80.30M (Peak 481.49M) | Time:01:06.64 | Compositing
# Fra:1 Mem:80.30M (Peak 481.49M) | Time:01:06.65 | Compositing | Initializing execution
# Fra:1 Mem:96.36M (Peak 481.49M) | Time:01:06.65 | Compositing | Operation 2-5
# Fra:1 Mem:144.36M (Peak 481.49M) | Time:01:06.67 | Compositing | Operation 3-5
# Fra:1 Mem:96.36M (Peak 481.49M) | Time:01:06.69 | Compositing | Operation 4-5
# Fra:1 Mem:160.36M (Peak 481.49M) | Time:01:06.70 | Compositing | Operation 5-5
# Fra:1 Mem:144.36M (Peak 481.49M) | Time:01:06.72 | Compositing | Operation 6-5
# Saved: '/disk2/data/shape_dataset/results_render/1/gt.png'
# Time: 01:07.40 (Saving: 00:00.68)

# %%
file = '0'

transformation, gt_transformation, acc, init_pose = renderer.load_transformation_data(file)
parts = renderer.load_mesh_parts(file, gt_transformation, init_pose)


if False:
    print(init_pose.shape)
    print(init_pose)
    print(transformation.shape)
    print(transformation)
    print(parts[0])

    #save_path = f"/work/users/j/a/jahn25/breaking-bad-dataset/results_render/{file}"
    #os.makedirs(save_path, exist_ok=True)
    #renderer.save_img(parts, gt_transformation, gt_transformation, init_pose, os.path.join(save_path, "gt.png"))

    #if True:
    #    renderer.clean()
    #    quit()

save_path = f"/work/users/j/a/jahn25/bio-dataset/results_render/{file}"
os.makedirs(save_path, exist_ok=True)
renderer.save_img(parts, gt_transformation, gt_transformation, init_pose, os.path.join(save_path, "gt.png"))

frame = 0

# bpy.ops.wm.save_mainfile(filepath=save_path + "test" + '.blend')

for i in range(transformation.shape[0]):
    renderer.render_parts(
        parts, 
        gt_transformation, 
        transformation[i], 
        init_pose, 
        frame,
    )
    frame += 1


imgs_path = os.path.join(save_path, "imgs")
os.makedirs(imgs_path, exist_ok=True)
renderer.save_video(imgs_path=imgs_path, video_path=os.path.join(save_path, "video.mp4"), frame=frame)
renderer.clean()



if True:
    quit()
# In[77]:


def debug_my():
    import numpy as np
    #everyday/BeerBottle/6da7fa9722b2a12d195232a03d04563a/fractured_1
    data_dict = np.load(os.path.join(project_home_dir, 'data/pc_data/everyday/val/00001.npz'))
    pc = data_dict['part_pcs_gt']
    data_id = data_dict['data_id'].item()
    part_valids = data_dict['part_valids']
    num_parts = data_dict["num_parts"].item()
    mesh_file_path = data_dict['mesh_file_path'].item()
    category = data_dict["category"]
    print('category',category)

    print('num_parts',num_parts)
    print('part_valids',part_valids)

    print('mesh_file_path',mesh_file_path)

    print('part_pcs_gt')
    print(pc.shape)
    print(pc)

debug_my(renderer.inference_path)


# In[5]:



# In[86]:


print(init_pose.shape)
print(init_pose)


# In[87]:


print(transformation.shape)
print(transformation)


# In[13]:


parts = renderer.load_mesh_parts(file, gt_transformation, init_pose)


# In[17]:


type(parts[0])
