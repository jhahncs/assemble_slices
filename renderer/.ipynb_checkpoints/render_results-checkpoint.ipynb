# %%
from myrenderer import MyRenderer
import os
import hydra
import json
import bpy
#sudo apt-get install ffmpeg


# In[3]:


from omegaconf import OmegaConf,open_dict
import omegaconf


# In[4]:

# %%
config_home_dir = '/users/j/a/jahn25/puzzlepp/config'
config_home_dir = '../config'

cfg_auto_aggl = omegaconf.OmegaConf.load(config_home_dir+'/auto_aggl.yaml')


cfg = OmegaConf.merge( cfg_auto_aggl )

data_home_dir = '/disk2/data/breaking_bad/'

cfg.experiment_output_path = ''
cfg.inference_dir= data_home_dir+'results_trained'
cfg.renderer.output_path = data_home_dir+'results_trained_render/'
cfg.renderer.mesh_path = data_home_dir

# %%
renderer = MyRenderer(cfg)


#save_dir = data_root_dir+'/results' #cfg.renderer.output_path
    
sampled_files = renderer.sample_data_files()
sampled_files = ['9']
# sampled_files = ["1"]

for file in sampled_files:
    transformation, gt_transformation, acc, init_pose = renderer.load_transformation_data(file)
    print('==============transformation===============')
    print(transformation)
    print('==============gt_transformation===============')
    print(gt_transformation)
    print('==============init_pose===============')
    print(init_pose)
    parts = renderer.load_mesh_parts(file, gt_transformation, init_pose)
    print(parts)
    save_path = cfg.renderer.output_path+f'{file}'
    os.makedirs(save_path, exist_ok=True)

    
    if True:
        renderer.clean()
        break


    renderer.save_img(parts, gt_transformation, gt_transformation, init_pose, os.path.join(save_path, "gt.png"))

    
    frame = 0

    # bpy.ops.wm.save_mainfile(filepath=save_path + "test" + '.blend')

    for i in range(transformation.shape[0]):
        renderer.render_parts(
            parts, 
            gt_transformation, 
            transformation[i], 
            init_pose, 
            frame,
        )
        frame += 1


    imgs_path = os.path.join(save_path, "imgs")
    os.makedirs(imgs_path, exist_ok=True)
    renderer.save_video(imgs_path=imgs_path, video_path=os.path.join(save_path, "video.mp4"), frame=frame)
    renderer.clean()


# In[ ]:
# Out:
# cycles rendering with: GPU
# Fra:1 Mem:11.03M (Peak 11.03M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | Plane
# Fra:1 Mem:11.03M (Peak 11.03M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:10.80M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:10.80M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:10.80M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:10.80M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Scene BVH | Building BVH 0%
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.08M, Peak:0.08M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.08M, Peak:0.08M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.08M, Peak:0.08M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:10.88M (Peak 11.03M) | Time:00:00.01 | Mem:0.08M, Peak:0.08M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:10.89M (Peak 11.03M) | Time:00:00.01 | Mem:0.00M, Peak:0.08M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:10.89M (Peak 11.03M) | Time:00:00.01 | Mem:0.09M, Peak:0.09M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:10.89M (Peak 11.03M) | Time:00:00.01 | Mem:0.09M, Peak:0.09M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:10.89M (Peak 11.03M) | Time:00:00.02 | Mem:0.09M, Peak:0.09M | Scene, ViewLayer | Sample 0/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:00:01.94 | Remaining:06:22.32 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 1/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:00:25.94 | Remaining:04:39.07 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 17/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:00:49.71 | Remaining:04:11.46 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 33/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:01:11.54 | Remaining:03:40.41 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 49/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:01:34.48 | Remaining:03:16.20 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 65/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:01:56.93 | Remaining:02:55.37 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 80/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:01:57.91 | Remaining:02:07.72 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 96/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:01:58.28 | Remaining:01:32.92 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 112/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:01:58.44 | Remaining:01:06.61 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 128/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:01:58.53 | Remaining:00:46.08 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 144/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:01:58.58 | Remaining:00:29.64 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 160/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:01:58.63 | Remaining:00:16.17 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 176/200
# Fra:1 Mem:283.10M (Peak 283.10M) | Time:01:58.68 | Remaining:00:04.94 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 192/200
# Fra:1 Mem:347.10M (Peak 475.10M) | Time:01:58.96 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Sample 200/200
# Fra:1 Mem:347.10M (Peak 475.10M) | Time:01:58.96 | Mem:272.09M, Peak:272.09M | Scene, ViewLayer | Finished
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /disk2/python_proj/puzzle/lib/python3.11/site-packages/bpy/4.2/scripts/addons_core/cycles/__init__.py:72, in CyclesRender.render(self, depsgraph)
#      71 def render(self, depsgraph):
# ---> 72     engine.render(self, depsgraph)
#
# File /disk2/python_proj/puzzle/lib/python3.11/site-packages/bpy/4.2/scripts/addons_core/cycles/engine.py:91, in render(engine, depsgraph)
#      89 import _cycles
#      90 if hasattr(engine, "session"):
# ---> 91     _cycles.render(engine.session, depsgraph.as_pointer())
#
# KeyboardInterrupt:
# Fra:1 Mem:75.02M (Peak 475.10M) | Time:01:59.14 | Compositing
# Fra:1 Mem:75.02M (Peak 475.10M) | Time:01:59.17 | Compositing | Initializing execution
# Fra:1 Mem:91.08M (Peak 475.10M) | Time:01:59.19 | Compositing | Operation 2-5
# Fra:1 Mem:139.08M (Peak 475.10M) | Time:01:59.21 | Compositing | Operation 3-5
# Fra:1 Mem:91.08M (Peak 475.10M) | Time:01:59.22 | Compositing | Operation 4-5
# Fra:1 Mem:155.08M (Peak 475.10M) | Time:01:59.23 | Compositing | Operation 5-5
# Fra:1 Mem:139.08M (Peak 475.10M) | Time:01:59.25 | Compositing | Operation 6-5
# Saved: '/disk2/data/breaking_bad/results_trained_render/9/gt.png'
# Time: 02:00.78 (Saving: 00:01.51)

# %%
file = '0'

transformation, gt_transformation, acc, init_pose = renderer.load_transformation_data(file)
parts = renderer.load_mesh_parts(file, gt_transformation, init_pose)


if False:
    print(init_pose.shape)
    print(init_pose)
    print(transformation.shape)
    print(transformation)
    print(parts[0])

    #save_path = f"/work/users/j/a/jahn25/breaking-bad-dataset/results_render/{file}"
    #os.makedirs(save_path, exist_ok=True)
    #renderer.save_img(parts, gt_transformation, gt_transformation, init_pose, os.path.join(save_path, "gt.png"))

    #if True:
    #    renderer.clean()
    #    quit()

save_path = f"/work/users/j/a/jahn25/bio-dataset/results_render/{file}"
os.makedirs(save_path, exist_ok=True)
renderer.save_img(parts, gt_transformation, gt_transformation, init_pose, os.path.join(save_path, "gt.png"))

frame = 0

# bpy.ops.wm.save_mainfile(filepath=save_path + "test" + '.blend')

for i in range(transformation.shape[0]):
    renderer.render_parts(
        parts, 
        gt_transformation, 
        transformation[i], 
        init_pose, 
        frame,
    )
    frame += 1


imgs_path = os.path.join(save_path, "imgs")
os.makedirs(imgs_path, exist_ok=True)
renderer.save_video(imgs_path=imgs_path, video_path=os.path.join(save_path, "video.mp4"), frame=frame)
renderer.clean()



if True:
    quit()
# In[77]:


def debug_my():
    import numpy as np
    #everyday/BeerBottle/6da7fa9722b2a12d195232a03d04563a/fractured_1
    data_dict = np.load(os.path.join(project_home_dir, 'data/pc_data/everyday/val/00001.npz'))
    pc = data_dict['part_pcs_gt']
    data_id = data_dict['data_id'].item()
    part_valids = data_dict['part_valids']
    num_parts = data_dict["num_parts"].item()
    mesh_file_path = data_dict['mesh_file_path'].item()
    category = data_dict["category"]
    print('category',category)

    print('num_parts',num_parts)
    print('part_valids',part_valids)

    print('mesh_file_path',mesh_file_path)

    print('part_pcs_gt')
    print(pc.shape)
    print(pc)

debug_my(renderer.inference_path)


# In[5]:



# In[86]:


print(init_pose.shape)
print(init_pose)


# In[87]:


print(transformation.shape)
print(transformation)


# In[13]:


parts = renderer.load_mesh_parts(file, gt_transformation, init_pose)


# In[17]:


type(parts[0])
